# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../csvFiles/movie_data.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Movie_name             11 non-null     object
#  1   Budget                 11 non-null     int64
#  2   Number_of_Celebraties  11 non-null     int64
#  3   Class                  11 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 480.0+ bytes

# %%
data.head()
# Out:
#   Movie_name     Budget  Number_of_Celebraties        Class
# 0        IBK   50211573                      3      Semihit
# 1        AJZ  175894273                      2          Hit
# 2        SRX  201963835                      2  Blockbuster
# 3        HWJ  433557714                      2  Blockbuster
# 4        HOU   37941039                      1         Flop

# %%
data.describe()
# Out:
#              Budget  Number_of_Celebraties
# count  1.100000e+01              11.000000
# mean   2.094172e+08               2.545455
# std    1.469858e+08               1.128152
# min    2.534624e+07               1.000000
# 25%    1.095606e+08               2.000000
# 50%    1.890003e+08               2.000000
# 75%    2.873482e+08               3.000000
# max    4.460677e+08               5.000000

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(10,6))
plt.bar(data["Movie_name"], data["Budget"], color="g")
plt.plot(data["Movie_name"], data["Budget"])
plt.xlabel("Movie")
plt.ylabel("Budget")
plt.title("Movie Budget")
plt.show()

# %%
plt.scatter(data["Number_of_Celebraties"], data["Budget"])
plt.xlabel("Number of Celebraties")
plt.ylabel("Budget")
plt.show()

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Budget'}>,
#         <Axes: title={'center': 'Number_of_Celebraties'}>]], dtype=object)
