# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Happiness.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        160 non-null    object
#  1   Region                         160 non-null    object
#  2   Happiness Rank                 160 non-null    int64
#  3   Happiness Score                159 non-null    float64
#  4   Standard Error                 160 non-null    float64
#  5   Economy (GDP per Capita)       160 non-null    float64
#  6   Family                         160 non-null    float64
#  7   Health (Life Expectancy)       160 non-null    float64
#  8   Freedom                        159 non-null    float64
#  9   Trust (Government Corruption)  160 non-null    float64
#  10  Generosity                     160 non-null    float64
#  11  Dystopia Residual              160 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.1+ KB

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
# 5         0.03140                   1.29025  1.31826
# 6         0.02799                   1.32944  1.28017
# 7         0.03157                   1.33171  1.28907
# 8         0.03371                   1.25018  1.31967
# 9         0.04083                   1.33358  1.30923
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
# 5                   0.88911  0.64169                        0.41372
# 6                   0.89284  0.61576                        0.31814
# 7                   0.91087  0.65980                        0.43844
# 8                   0.90837  0.63938                        0.42922
# 9                   0.93156  0.65124                        0.35637
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176
# 5     0.23351            2.61955
# 6     0.47610            2.46570
# 7     0.36262            2.37119
# 8     0.47501            2.26425
# 9     0.43562            2.26646

# %%
df.fillna(df.median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        160 non-null    object
#  1   Region                         160 non-null    object
#  2   Happiness Rank                 160 non-null    int64
#  3   Happiness Score                160 non-null    float64
#  4   Standard Error                 160 non-null    float64
#  5   Economy (GDP per Capita)       160 non-null    float64
#  6   Family                         160 non-null    float64
#  7   Health (Life Expectancy)       160 non-null    float64
#  8   Freedom                        160 non-null    float64
#  9   Trust (Government Corruption)  160 non-null    float64
#  10  Generosity                     160 non-null    float64
#  11  Dystopia Residual              160 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 15.1+ KB
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9984\3738176735.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.median(), inplace=True)

# %%
print(df.duplicated())
df.drop_duplicates(inplace=True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 155    False
# 156    False
# 157    False
# 158    False
# 159     True
# Length: 160, dtype: bool

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      159.000000       159.000000      159.000000
# mean        79.987421         5.595428        0.048007
# std         46.032320         2.234785        0.017161
# min          1.000000         2.839000        0.018480
# 25%         40.500000         4.557500        0.037275
# 50%         80.000000         5.253000        0.043940
# 75%        119.500000         6.282000        0.052335
# max        158.000000        25.000000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                159.000000  159.000000                159.000000
# mean                   0.842128    0.985693                  0.628084
# std                    0.405011    0.279770                  0.247817
# min                    0.000000    0.000000                  0.000000
# 25%                    0.533325    0.853755                  0.437065
# 50%                    0.901980    1.026260                  0.696390
# 75%                    1.156985    1.212570                  0.810425
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  159.000000                     159.000000  159.000000
# mean     0.427018                       0.143195    0.236852
# std      0.149485                       0.119688    0.126407
# min      0.000000                       0.000000    0.000000
# 25%      0.328480                       0.061890    0.151285
# 50%      0.434500                       0.107310    0.215420
# 75%      0.544280                       0.179910    0.308715
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         159.000000
# mean            2.095633
# std             0.553404
# min             0.328580
# 25%             1.756165
# 50%             2.090660
# 75%             2.459520
# max             3.602140

# %%
df.boxplot(by="Region", column=["Happiness Score"],figsize=(20,5))
# Out:
# <AxesSubplot:title={'center':'Happiness Score'}, xlabel='Region'>

# %%
def outlier_removal(df, column_name):
    sorted(column_name)
    Q2 = df[column_name].median()
    Q1 = np.percentile(df[column_name], 25, interpolation = 'midpoint')
    Q3 = np.percentile(df[column_name], 75, interpolation = 'midpoint')
    iqr = Q3 - Q1
    low = Q1 - 1.5 * iqr
    high = Q3 + 1.5 * iqr
    df.drop(df.index[(df[column_name] > high)],axis=0,inplace=True)
    df.drop(df.index[(df[column_name] < low)],axis=0,inplace=True)
    
            
            
outlier_removal(df,"Happiness Score")
print(df["Happiness Score"].var())
df.describe()
# Out:
# 1.2678467687408137
#        Happiness Rank  Happiness Score  Standard Error  \
# count      157.000000       157.000000       157.00000
# mean        79.006369         5.380083         0.04787
# std         45.487600         1.125987         0.01720
# min          1.000000         2.839000         0.01848
# 25%         40.000000         4.550000         0.03726
# 50%         79.000000         5.253000         0.04394
# 75%        118.000000         6.168000         0.05232
# max        158.000000         7.587000         0.13693
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                157.000000  157.000000                157.000000
# mean                   0.847302    0.994334                  0.629675
# std                    0.404144    0.270077                  0.247759
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545580    0.860400                  0.438730
# 50%                    0.918510    1.032760                  0.696390
# 75%                    1.159910    1.216240                  0.811600
# max                    1.690420    1.402230                  1.025250
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  157.000000                     157.000000  157.000000
# mean     0.429137                       0.143131    0.235802
# std      0.148778                       0.120362    0.125687
# min      0.000000                       0.000000    0.000000
# 25%      0.328780                       0.061460    0.149820
# 50%      0.434770                       0.107130    0.215420
# 75%      0.546040                       0.179220    0.306380
# max      0.669730                       0.551910    0.795880
#
#        Dystopia Residual
# count         157.000000
# mean            2.110253
# std             0.536807
# min             0.654290
# 25%             1.761450
# 50%             2.100170
# 75%             2.465310
# max             3.602140

# %%
df.hist(column="Happiness Score")
# Out:
# array([[<AxesSubplot:title={'center':'Happiness Score'}>]], dtype=object)

# %%
from sklearn import preprocessing

df[["Happiness Score"]] =  preprocessing.StandardScaler().fit(df[["Happiness Score"]])
df.describe()
# Out:
#        Happiness Rank  Standard Error  Economy (GDP per Capita)      Family  \
# count      157.000000       157.00000                157.000000  157.000000
# mean        79.006369         0.04787                  0.847302    0.994334
# std         45.487600         0.01720                  0.404144    0.270077
# min          1.000000         0.01848                  0.000000    0.000000
# 25%         40.000000         0.03726                  0.545580    0.860400
# 50%         79.000000         0.04394                  0.918510    1.032760
# 75%        118.000000         0.05232                  1.159910    1.216240
# max        158.000000         0.13693                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                157.000000  157.000000                     157.000000
# mean                   0.629675    0.429137                       0.143131
# std                    0.247759    0.148778                       0.120362
# min                    0.000000    0.000000                       0.000000
# 25%                    0.438730    0.328780                       0.061460
# 50%                    0.696390    0.434770                       0.107130
# 75%                    0.811600    0.546040                       0.179220
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  157.000000         157.000000
# mean     0.235802           2.110253
# std      0.125687           0.536807
# min      0.000000           0.654290
# 25%      0.149820           1.761450
# 50%      0.215420           2.100170
# 75%      0.306380           2.465310
# max      0.795880           3.602140

# %%
import seaborn as sns

sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")
# Out:
# <AxesSubplot:>
